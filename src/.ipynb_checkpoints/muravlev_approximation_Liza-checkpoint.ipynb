# %%
from fbm import FBM
import numpy as np
import scipy.integrate
from matplotlib import pyplot as plt

# %%
import importlib
import muravlev_approximation
importlib.reload(muravlev_approximation)
from muravlev_approximation import fbm_muravlev
from hurst_estimation import m_estimator, w_estimator

# %% [markdown]
# ## Muravlev's method for fBM simulation
#
# Let $\xi=(\xi_\beta)_{\beta>0}$ be a Gaussian process with zero mean and covariance function
# $$
# \mathrm{cov}(\xi_\alpha, \xi_\beta) = \frac{1}{\alpha+\beta}, \qquad \alpha,\beta>0.
# $$
#
# Let $B_t$ be a Brownian motion independent of $\xi$. Define the family of Ornstein-Uhlenbeck processes $Z^\beta = (Z_t^\beta)_{t\ge 0}$ driven by the same Brownian motion $B_t$:
# $$
# d Z_t^\beta = -\beta Z_t^\beta dt + d B_t, \qquad Z_0^\beta = \xi_\beta.
# $$
#
# Then for $H\in(0,\frac12)$ we have the following representation:
# $$
# B_t^H = c_H \int_0^\infty \beta^{-1/2-H} (Z_t^\beta - \xi_\beta) d \beta,
# $$
# where $c_H$ is some constant.
#
# Simulation of the process for the uniform grid:
# 1. Take $\beta_j = j\Delta \beta_j, j=1,\dots,k$, and simulate the value of $\xi_{\beta_j}$ from the multivariate normal distribution.
#
# 2. Simulate a trajectory of the Brownian motion at points $t_i = i\Delta t$, $i=0,\dots,n$.
#
# 3. Simulate $k$ OU processes with the above $\beta_j$ using Euler's scheme.
#
# 4. Approximate the integral by
# $$
# B_{t_i}^H \approx \sum_{j=1}^k \beta_j^{-1/2-H} (Z_{t_i}^{\beta_j}-\xi_{\beta_j}) \Delta \beta_j.
# $$

# %% [markdown]
# #### Parameters

# %%
n = 4096
H = 0.2

# %% [markdown]
# #### Reference fBM

# %%
time_grid = np.linspace(0, 1, n+1)
ref_fbm = FBM(n=n, hurst=H, length=1, method='daviesharte').fbm()

_, ax = plt.subplots(figsize=(8, 5))
ax.plot(time_grid, ref_fbm)
ax.set_title("Reference fBM process")
ax.grid()

# %%
H = 0.2
muravlev_fbm = fbm_muravlev(n=n, hurst=H, n_beta=3000, beta_max=6000, uniform_beta = True, plotting=True)

# %% [markdown]
# #### Comparison of hurst estimations:

# %%
m_estimator(ref_fbm), m_estimator(muravlev_fbm)
# Out:
# (0.16855362282784483, 0.21494854714459283)

# %%
H = 0.4
muravlev_fbm = fbm_muravlev(n=n, hurst=H, n_beta=3000, beta_max=6000, uniform_beta = True, plotting=True)

# %%
m_estimator(ref_fbm), m_estimator(muravlev_fbm)
# Out:
# (0.3931043841361468, 0.34283747399843656)

# %% [markdown]
# ## Observations

# %% [markdown]
# **Uniform $\beta$-grid**
#
# 1. The results significantly depend on the truncation value *beta_max* of beta given *n_beta* fixed. Rough processes need greater value of *beta_max*, for the processes with $H \approx 0.4$ the intergral converges faster and the integrand varies more, so in this case more accurate grid around zero is needed.
# 2. The most time-consuming part of simulation is a simulation of the process $\xi_\beta$ for large values of *n_beta*. This problem can be solved by using non-uniform grid of change of the variables in the integral.
# 3. For very large values of $\beta$, when $\beta \Delta t > 2$, numerical problems occur in OU simulation.
# 4. Computation time depends mostly on the size of covariance matrix of $\xi_\beta$ rather than the time grid size.

# %% [markdown]
# ## Theoretical TODOs

# %% [markdown]
# 1. Change the variables in the integral for the limits to be $(-1, 1)$. Transform it to the form appropriate for usage of Gaussian-Jacobi quadrature.
# 2. Analyze the smoothness of $Z_t^\beta - \xi_\beta$ w.r.t. to $\beta$. Calcuate its correlation function to understand how much the integrand varies w.r.t $\beta$.
# 3. Propose an approach allowing for faster simulation of $\xi_\beta$.

# %% [markdown]
# ## Experiments

# %% [markdown]
# **Uniform $\beta$-grid**
#
# 1. **Hypothesis**: the quality of simulation does not depend on the size of time grid. **Experiment**: Fix the values of *n_beta* and *beta_max*, simulate trajectories on different time grids and compare their Hurst exponents.
#
# **Non-uniform $\beta$-grid**
# 1. Try to use logarithmic grid and use trapz to approximate integral.
# 2. After change of the variables try to use Gauss-Jacobi quadrature.

# %% [markdown]
# **Non-uniform $\beta$-grid**

# %%
H = 0.2
n = 10000
muravlev_fbm = fbm_muravlev(n=n, hurst=H, n_beta=5000, beta_max=20000, uniform_beta = False, plotting=True)

# %%
m_estimator(ref_fbm), m_estimator(muravlev_fbm)
# Out:
# (0.20674664112250912, 0.2299168451888337)

# %%
H = 0.2
n = 4096
muravlev_fbm = fbm_muravlev(n=n, hurst=H, n_beta=3000, beta_max=8000, uniform_beta = False, plotting=True)

# %%
m_estimator(muravlev_fbm)
# Out:
# 0.22858744934731884

# %% [markdown]
# **Different time grids**

# %%
n_paths = 100

H_uni = np.zeros((5, n_paths))
H_nuni = np.zeros((5, n_paths))
H_ref = np.zeros((5, n_paths))

# %%
for i in range(n_paths):
    ref_fbm = FBM(n=4096, hurst=H, length=1, method='daviesharte').fbm()
    H_ref [0][i]= m_estimator(ref_fbm)
    
    muravlev_fbm = fbm_muravlev(n=4096, hurst=H, n_beta=2000, beta_max=8000)
    H_uni[0][i] = m_estimator(muravlev_fbm)
    
    muravlev_fbm = fbm_muravlev(n=4096, hurst=H, n_beta=2000, beta_max=8000, uniform_beta = False)
    H_nuni[0][i] = m_estimator(muravlev_fbm)

# %%
# Creating plot
plt.boxplot([H_ref[0], H_uni[0], H_nuni[0]])
 
# show plot
plt.show()

# %%
for i in range(n_paths):
    ref_fbm = FBM(n=10000, hurst=H, length=1, method='daviesharte').fbm()
    H_ref [1][i]= m_estimator(ref_fbm)
    
    muravlev_fbm = fbm_muravlev(n=10000, hurst=H, n_beta=2000, beta_max=8000)
    H_uni[1][i] = m_estimator(muravlev_fbm)
    
    muravlev_fbm = fbm_muravlev(n=10000, hurst=H, n_beta=2000, beta_max=8000, uniform_beta = False)
    H_nuni[1][i] = m_estimator(muravlev_fbm)

# %%
# Creating plot
plt.boxplot([H_ref[1], H_uni[1], H_nuni[1]])
 
# show plot
plt.show()

# %%
for i in range(n_paths):
    ref_fbm = FBM(n=20000, hurst=H, length=1, method='daviesharte').fbm()
    H_ref [2][i]= m_estimator(ref_fbm)
    
    muravlev_fbm = fbm_muravlev(n=20000, hurst=H, n_beta=2000, beta_max=8000)
    H_uni[2][i] = m_estimator(muravlev_fbm)
    
    muravlev_fbm = fbm_muravlev(n=20000, hurst=H, n_beta=2000, beta_max=8000, uniform_beta = False)
    H_nuni[2][i] = m_estimator(muravlev_fbm)

# %%
# Creating plot
plt.boxplot([H_ref[2], H_uni[2], H_nuni[2]])
 
# show plot
plt.show()

# %%
for i in range(n_paths):
    ref_fbm = FBM(n=40000, hurst=H, length=1, method='daviesharte').fbm()
    H_ref [3][i]= m_estimator(ref_fbm)
    
    muravlev_fbm = fbm_muravlev(n=40000, hurst=H, n_beta=2000, beta_max=8000)
    H_uni[3][i] = m_estimator(muravlev_fbm)
    
    muravlev_fbm = fbm_muravlev(n=40000, hurst=H, n_beta=2000, beta_max=8000, uniform_beta = False)
    H_nuni[3][i] = m_estimator(muravlev_fbm)

# %%
# Creating plot
plt.boxplot([H_ref[3], H_uni[3], H_nuni[3]])
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot([H_ref[0], H_uni[0], H_nuni[0], H_ref[1], H_uni[1], H_nuni[1], H_ref[2], H_uni[2], H_nuni[3], H_ref[3], H_uni[3], H_nuni[3]])
 
# show plot
plt.show()
